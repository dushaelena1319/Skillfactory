# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
winecl = pd.read_csv('wine_cleared.csv', sep=',')
winecl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   country                129908 non-null  object
#  2   description            129971 non-null  object
#  3   designation            129971 non-null  object
#  4   points                 129971 non-null  int64
#  5   price                  129971 non-null  float64
#  6   province               129908 non-null  object
#  7   region_1               129971 non-null  object
#  8   taster_name            129971 non-null  object
#  9   taster_twitter_handle  129971 non-null  object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 12.9+ MB

# %%
winecl.info()

# %%
winecl['price'].min()
# Out:
# 4.0

# %%
winecl['points'].min()
# Out:
# 80

# %%
import statistics

# %%
mean = sum(winecl['price']) / len(winecl['price'])
print(mean)
# Out:
# 35.36338912999136

# %%
from statistics import median
med = median(winecl['price'])
print(med)
# Out:
# 28.0

# %%
from statistics import mode
mod = mode(winecl['price'])
print(mod)
# Out:
# 35.363389129985535

# %%
import matplotlib.pyplot as plt # библиотека визуализации
from scipy import stats # библиотека для расчетов

plt.subplot(1, 2, 1) # задаем сетку рисунка количество строк и столбцов
stats.probplot(winecl['price'], plot=plt) # qq plot

plt.subplot(1, 2, 2) # располагаем второй рисунок рядом
plt.hist(winecl['price']) # гистограмма распределения признака

plt.tight_layout() # чтобы графики не наезжали другу на друга, используем tight_layout

plt.show() # просмотр графика

# %%
import matplotlib.pyplot as plt # библиотека визуализации
from scipy import stats # библиотека для расчетов

plt.subplot(1, 2, 1) # задаем сетку рисунка количество строк и столбцов
stats.probplot(winecl['points'], plot=plt) # qq plot

plt.subplot(1, 2, 2) # располагаем второй рисунок рядом
plt.hist(winecl['points']) # гистограмма распределения признака

plt.tight_layout() # чтобы графики не наезжали другу на друга, используем tight_layout

plt.show() # просмотр графика

# %%
display(winecl[['price', 'points']].corr())
# Out:
#            price    points
# price   1.000000  0.402137
# points  0.402137  1.000000

# %%
display(winecl[['price', 'points']].corr('spearman'))
# Out:
#            price    points
# price   1.000000  0.581095
# points  0.581095  1.000000

# %%
display(winecl[['price', 'points']].corr('kendall'))
# Out:
#            price    points
# price   1.000000  0.433498
# points  0.433498  1.000000

# %%
from sklearn.metrics import matthews_corrcoef

# %%
from sklearn.metrics import matthews_corrcoef

x = [+1, -1, +1, +1] # список значений признака х
y = [+1, +1, +1, -1] # список значений признака y

matthews_corrcoef(x, y) # рассчитаем коэффициент корреляции Мэтьюса
# Out:
# -0.3333333333333333
